# %%
import tensorflow as tf

# %%
### 索引

# %%
# 创建4维张量（4张彩色图片）
x = tf.random.normal([4,32,32,3])

# %%
# 取第 1 张图片的数据
x[0]
# Out:
# <tf.Tensor: shape=(32, 32, 3), dtype=float32, numpy=
# array([[[-0.18027598,  0.9540487 , -0.4593162 ],
#         [ 0.47916305, -1.0379349 ,  0.80905306],
#         [-1.0495822 ,  0.88050073,  0.08185571],
#         ...,
#         [ 0.8192562 , -0.3520053 , -2.1027572 ],
#         [ 2.449665  , -1.4130754 ,  2.2820776 ],
#         [ 0.4887177 ,  1.3125634 , -0.02116959]],
#
#        [[ 0.7492407 , -0.2715708 ,  0.37467617],
#         [ 0.83842736,  0.34928247,  0.34488165],
#         [-0.8613825 , -0.35168755,  0.5603118 ],
#         ...,
#         [ 1.3735404 ,  0.27020192,  0.5576199 ],
#         [ 1.3300408 , -0.02496228,  0.88533413],
#         [ 2.246438  ,  0.8167357 , -0.3437823 ]],
#
#        [[-1.6759372 , -1.3732558 ,  1.9001026 ],
#         [-2.5563045 ,  1.2326422 ,  1.3919244 ],
#         [-0.48795074, -1.24595   ,  0.6591501 ],
#         ...,
#         [ 0.7079578 , -1.6652666 ,  1.6656109 ],
#         [-0.14659573,  1.182277  ,  0.6110125 ],
#         [-0.22247958, -0.17453763,  1.1493992 ]],
#
#        ...,
#
#        [[-0.83051014,  0.2842376 , -1.7367504 ],
#         [ 0.66340905,  0.5452862 , -0.5949142 ],
#         [-1.878379  ,  0.33419824,  1.2063088 ],
#         ...,
#         [-0.44925758,  1.0738021 , -0.81374526],
#         [ 0.14385986, -0.8449309 , -0.13116653],
#         [-0.51414466,  0.03734379,  0.8187796 ]],
#
#        [[ 1.7002884 ,  0.19822071, -0.0314494 ],
#         [-0.77322817,  0.9019693 ,  1.3155085 ],
#         [ 0.5516392 , -3.01486   ,  0.4588548 ],
#         ...,
#         [ 2.1246564 ,  0.43173853,  0.1799768 ],
#         [-1.804028  , -0.8186786 , -0.734304  ],
#         [ 1.0076885 ,  0.6465628 ,  0.6326263 ]],
#
#        [[-0.791861  ,  0.11882208,  0.2824528 ],
#         [ 0.46812314, -0.15029925, -1.2948122 ],
#         [-0.54398286,  0.00818753,  0.9250136 ],
#         ...,
#         [ 0.03605703,  2.5343723 ,  1.0800774 ],
#         [ 1.1410983 , -1.132439  ,  2.8475986 ],
#         [ 0.1960442 ,  0.11704498, -0.51787615]]], dtype=float32)>

# %%
# 取第 1 张图片的第 2 行
x[0][1]
# Out:
# <tf.Tensor: shape=(32, 3), dtype=float32, numpy=
# array([[ 0.7492407 , -0.2715708 ,  0.37467617],
#        [ 0.83842736,  0.34928247,  0.34488165],
#        [-0.8613825 , -0.35168755,  0.5603118 ],
#        [ 0.7629353 , -1.1331805 ,  0.3304656 ],
#        [-0.72146505,  2.1595342 , -0.12128511],
#        [-0.4034748 , -2.248676  , -0.17080255],
#        [ 0.54077923, -1.2068259 ,  0.19820638],
#        [-0.98951596,  1.2108873 ,  1.167212  ],
#        [ 1.0170045 ,  0.5619506 , -0.92357826],
#        [-0.18719867,  0.21374671,  0.15017891],
#        [ 0.4616921 ,  0.399425  ,  2.114249  ],
#        [-0.51299465,  1.4896525 , -0.64868456],
#        [ 0.44814542, -0.8273785 ,  0.98001397],
#        [-0.62752324,  0.45318514,  0.8247997 ],
#        [ 0.42954078,  1.3751421 , -0.3173129 ],
#        [ 0.07558331,  1.1941308 , -1.2221116 ],
#        [ 0.7600544 , -1.7406693 , -0.6171176 ],
#        [-0.48116165,  0.86197746,  1.5537226 ],
#        [ 0.37632024,  0.4584467 ,  1.1252471 ],
#        [ 0.33324116,  1.6663679 , -0.70396805],
#        [ 0.33854455,  0.16332027,  0.81084174],
#        [-0.2025438 , -0.90051347, -0.5527959 ],
#        [ 1.0249003 ,  0.8961486 , -0.73564744],
#        [ 0.67497754,  0.6882311 , -1.317271  ],
#        [ 2.5867581 , -0.132013  , -0.39490226],
#        [-1.067494  , -0.6166765 , -0.52804345],
#        [-1.5121657 ,  0.7884802 ,  1.695965  ],
#        [-0.68204945, -0.02511865,  0.9665638 ],
#        [-0.8024112 ,  1.2967463 , -0.67790866],
#        [ 1.3735404 ,  0.27020192,  0.5576199 ],
#        [ 1.3300408 , -0.02496228,  0.88533413],
#        [ 2.246438  ,  0.8167357 , -0.3437823 ]], dtype=float32)>

# %%
# 取第 1 张图片，第 2 行，第 3 列的数据
x[0][1][2]
# Out:
# <tf.Tensor: shape=(3,), dtype=float32, numpy=array([-0.8613825 , -0.35168755,  0.5603118 ], dtype=float32)>

# %%
# 取第 3 张图片，第 2 行，第 1 列的像素， B 通道(第 2 个通道)颜色强度值
x[2][1][0][1]
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.93156004>
